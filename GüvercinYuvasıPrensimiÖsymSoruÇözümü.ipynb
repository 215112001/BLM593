# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %%
vagonlar = [6,13,9] 
  
vagonlar.sort() 
  
print("Boş Koltuk Sayısı En az Olan Vagondaki Boş Koltuk Sayısı:", vagonlar[0])
# Out:
# Boş Koltuk Sayısı En az Olan Vagondaki Boş Koltuk Sayısı: 6

# %%
print("Her Vagondan Birer Bilet Satışını Garantilemek İçin Satılması Gereken Bilet Sayısı : ",sum(vagonlar)-vagonlar[0]+1)
# Out:
# Her Vagondan Birer Bilet Satışını Garantilemek İçin Satılması Gereken Bilet Sayısı :  23

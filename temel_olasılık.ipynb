# %% [markdown]
# ![_kirilma1[1].jpg](data:image/jpeg;base64,...)

# %%
import random
ucgen=0
for i in range(10):
  nokta = [random.random(),random.random()]
  nokta.sort()
  a,b,c = nokta[0],nokta[1]-nokta[0],1-nokta[1]
  print ( a,b,c)
  if a+b>c and a+c>b and b+c>a:
    ucgen+=1
print(ucgen/10)
# Out:
# 0.28461734414403783 0.6408096703040086 0.07457298555195357
# 0.6879579994931654 0.2746013271263761 0.03744067338045853
# 0.3127981186872416 0.16404515160615596 0.5231567297066024
# 0.1509544986021073 0.320706195690763 0.5283393057071297
# 0.15015126553952418 0.36844659171031524 0.4814021427501606
# 0.7362121611475722 0.02417653410178555 0.2396113047506423
# 0.6921169073471781 0.13053315074628025 0.17734994190654163
# 0.37924425327811473 0.4279456835982466 0.1928100631236387
# 0.5164605952618234 0.35395959881520545 0.12957980592297114
# 0.14772364950554728 0.22411373604457274 0.62816261444988
# 0.2

# %%
import random
ucgen=0
for i in range(100000):
  nokta = [random.random(),random.random()]
  nokta.sort()
  a,b,c = nokta[0],nokta[1]-nokta[0],1-nokta[1]
  if a+b>c and a+c>b and b+c>a:
    ucgen+=1
print(ucgen/100000)
# Out:
# 0.24962
